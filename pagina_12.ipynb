# %%
# https://www.pagina12.com.ar/

# %%
# Imports
import requests
from IPython.display import Image
from bs4 import BeautifulSoup

# %%
URL = 'https://www.pagina12.com.ar/'

# %%
# Descarga la pagina de la URL
page12 = requests.get(URL)

# Se verifica el stado, y ya obtememos el html
print(page12.status_code)

# Se puede ver el texto en raw del html
print(page12.text)
# Out:
# 200
# <!DOCTYPE html><html class="no-js"><head><meta charset="utf-8"><title>Página12 | La otra mirada</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}</script><meta property="description" name="description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="fb:pages" name="fb:pages" content="1541638399393436"><meta property="og:locale" name="og:locale" content="es_AR"><meta property="og:title" name="og:title" content="Página12 | La otra mirada"><meta property="og:site_name" name="og:site_name" content="PAGINA12"><meta property="og:type" name="og:type" content="website"><meta property="og:url" name="og:url" content="https://www.pagina12.com.ar"><meta property="og:description" name="og:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:title" name="twitter:title" content="Página12 | La otra mirada"><meta property="twitter:description" name="twitter:description" content="Notas focalizadas en el quehacer político de la Argentina."><meta property="twitter:creator" name="twitter:creator" content="@Pagina12"><meta property="twitter:site" name="twitter:site" content="@pagina12"><meta property="article:author" name="article:author" content="Página12"><meta property="article:publisher" name="article:publisher" content="https://www.facebook.com/Pagina12ok"><meta name="share_cdn_host" content="https://www.pagina12.com.ar"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" /><link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css"><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Archivo+Narrow|Lora:400,400i|Oswald:300,400,700,800|Open+Sans+Condensed:300,700|Open+Sans:300,300i,400,400i,600,600i,700,800&display=swap"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.285" media="screen"><link rel="stylesheet" href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.285" media="print"><link rel="shortcut icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.285" type="image/x-icon"><link rel="icon" href="https://www.pagina12.com.ar/favicon.ico?v=1.0.285" type="image/x-icon"><link rel="apple-touch-icon" sizes="57x57" href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.285"><link rel="apple-touch-icon" sizes="72x72" href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.285"><link rel="apple-touch-icon" sizes="114x114" href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.285"><link rel="apple-touch-icon" sizes="120x120" href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.285"><link rel="apple-touch-icon" sizes="144x144" href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.285"><link rel="apple-touch-icon" sizes="152x152" href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.285"><script>dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "-"});dataLayer.push({"module": "p12_home"});dataLayer.push({"enviroment": "production"});dataLayer.push({"userLoggedIn": "0"});dataLayer.push({"userContributor": "0"});</script><script>(function(w,d, ...
# Estás escuelas han realizado excelentes análisis de las condiciones de vida bajo...</div><div class="time-author-wrapper article-ta "><span class="article-author"><span>Por </span><a class="no-link">Jorge Alemán</a></span></div></div></article></div></div></div></div><div class="text-center iframe-margin-top hide-for-medium"><div id="div-gpt-ad-1503943435188-6"></div></div></div><div class="wrapper"><div class="layout-region"><div class="show-for-large"><div class="widget authorsOfToday authorsOfToday--regular"><div class="list-container"><div class="title">Escriben hoy:</div><ul class="list"><li><a href="/autores/128043-alejandro-duchini">Alejandro Duchini</a></li><li><a href="/autores/640-beatriz-vignoli">Beatriz Vignoli</a></li><li><a href="/autores/1988-carlos-noriega">Carlos Noriega</a></li><li><a href="/autores/1992-carolina-prieto">Carolina Prieto</a></li><li><a href="/autores/648-cristian-vitale">Cristian Vitale</a></li><li><a href="/autores/8445-elena-llorente">Elena Llorente</a></li><li><a href="/autores/664-emanuel-respighi">Emanuel Respighi</a></li><li><a href="/autores/3887-emir-sader">Emir Sader</a></li><li><a href="/autores/5027-florencia-saintout">Florencia Saintout</a></li><li><a href="/autores/851-irina-hauser">Irina Hauser</a></li><li><a href="/autores/852-javier-lewkowicz">Javier Lewkowicz</a></li><li><a href="/autores/13846-jorge-aleman">Jorge Alemán</a></li><li><a href="/autores/120118-jose-maggi">José Maggi</a></li><li><a href="/338316-las-orejas-caidas">Juan Cruz Pistilli</a></li><li><a href="/autores/874-leonel-lenga">Leonel Lenga</a></li><li><a href="/autores/289094-luciana-bertoia">Luciana Bertoia</a></li><li><a href="/autores/217276-maira-lopez">Maira López</a></li><li><a href="/autores/5284-marcelo-justo">Marcelo Justo</a></li><li><a href="/autores/227456-maria-cafferata">María Cafferata</a></li><li><a href="/autores/237906-melisa-molina">Melisa Molina</a></li><li><a href="/autores/899-miguel-jorquesa">Miguel Jorquera</a></li><li><a href="/autores/272523-natali-risso">Natalí Risso</a></li><li><a href="/autores/217443-nicolas-hirtz">Nicolás Hirtz</a></li><li><a href="/autores/912-oscar-ranzani">Oscar Ranzani</a></li><li><a href="/autores/287997-patricia-chaina">Patricia Chaina</a></li><li><a href="/autores/237284-pedro-peretti">Pedro Peretti</a></li><li><a href="/autores/1239-raul-kollmann">Raúl Kollmann</a></li><li><a href="/autores/64302-santiago-giordano">Santiago Giordano</a></li></ul><div class="read-more hidden"><span class="label-more">Ver más</span><span class="hidden label-less">Ver menos</span><span class="caret bottom"></span><span class="caret top hidden"></span></div></div></div></div><div class="hide-for-large"><div class="widget authorsOfToday authorsOfToday--mobile"><div class="authorsOfToday--top"><div class="column right"><div class="read-more hidden"><span class="label-more">Ver más</span><span class="hidden label-less">Ver menos</span><span class="caret bottom"></span><span class="caret top hidden"></span></div></div><div class="column left"><div class="title">Escriben hoy:</div></div></div><div class="divider"></div><div class="list-container"><ul class="list column small-12"><li><a href="/autores/128043-alejandro-duchini">Alejandro Duchini</a></li><li><a href="/autores/640-beatriz-vignoli">Beatriz Vignoli</a></li><li><a href="/autores
." share-img="https://www.pagina12.com.ar/assets/media/FallBack-Logo.jpg" share-body="&lt;p&gt;“Me parece pésimo que utilicen a los chicos para una cosa así”. Jorge Serrano, autor de “La Guitarra”, se indignó al enterarse de que desde la Usina del Arte, dependiente del gobierno porteño, se invitaba a nenes a grabar un video al ritmo del tema de Los Auténticos Decadentes pero alterando la letra. “Porque yo sí quiero ira a estudiar, sí quiero ir a jugar. Ya no aguanto más, quiero poder ir al cole muchos días y que la gente nos ayude por favor”, canta una voz infantil para ser imitada. “No entiendo el desquicio de la persona que eligió justo una canción que habla de no ir a estudiar ni a trabajar. Me parece muy irónico”, comentó Serrano a PáginaI12. La elección de temas no es el fuerte de estos adoctrinadores.&lt;/p&gt;
# "><li class="twitter"><span class="share fonticon-twitter big"></span></li><li class="facebook"><span class="share fonticon-facebook big"></span></li><li class="mail"><span class="share fonticon-mail big"></span></li><li class="whatsapp hide-for-medium"><span class="share fonticon-whatsapp big"></span></li><li class="telegram hide-for-medium"><span class="share fonticon-telegram big"></span></li></ul></div></div></div></div></div></div></div></div><div class="text-center iframe-margin-top hide-for-medium"><div id="div-gpt-ad-1506537706019-0"></div></div></div><div class="wrapper"><div class="home-humor-rep"><div class="widget humor-rep-single-block region-rep"><div style="text-align: center;"><div class="humor-container-block column"><div id="humor-scroll" data-toggle="humor-rep-cover" class="container-rep object-fit"><a href="https://www.pagina12.com.ar/humor/rep/338417"><img src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif" class="lazyload humor-main-img " data-src="https://images.pagina12.com.ar/styles/width960/public/2021-04/na40di01_17.jpg?itok=8ERl-WLT" alt="Humor" /></a></div><ul class="social-media big" share-title="REP" share-data="humor-container-block" share-url="https://www.pagina12.com.ar/humor/rep/338417" share-img="https://images.pagina12.com.ar/styles/width960/public/2021-04/na40di01_17.jpg?itok=8ERl-WLT"><li class="twitter"><span class="share fonticon-twitter big"></span></li><li class="facebook"><span class="share fonticon-facebook big"></span></li><li class="mail"><span class="share fonticon-mail big"></span></li><li class="whatsapp"><span class="share fonticon-whatsapp big hide-for-medium"></span></li><li class="telegram"><span class="share fonticon-telegram big hide-for-medium"></span></li></ul></div></div></div></div></div><div class="wrapper"><div class="layout-region region-suplementos region-suplementos-r12"><div class="r12-wrapper"><div class="r12-articles"><div class="r12-article xsmall-12"><div class="article-category-list suplemento-wrapper"><div class="title-box"><a href="https://www.pagina12.com.ar/suplementos/rosario12"><div class="title-img-wrapper rosario12-home"><img src="https://www.pagina12.com.ar/assets/media/logos/logo_rosario12_n.svg?v=1.0.285" alt="" /></div></a><div class="title-box_btn"><a href="https://www.pagina12.com.ar/suplementos/rosario12">Ver más</a></div></div><div class="supplement-headlines"> <div class="headline-card headline-6 "><article class="headline-card-inner"><div class="block-multimedia"><div class="multimedia-container"><a href="https://www.pagina12.com.ar/338145-alto-acatamiento-en-noche-rosarina"><div class="intrinsic-container"><img class="show-for-small-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.285" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2021-04/158244-ro03fo0127.jpg?itok=nTAN42ZV" alt="Javkin y Lagna coincidieron en el análisis. (Fuente: Prensa Gobernación)"><img class="show-for-medium-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.285" data-src="https://images.pagina12.com.ar/styles/focal_16_9_960x540/public/2021-04/158244-ro03fo0127.jpg?itok=Krysr4kc" alt="Javkin y Lagna coincidieron en el análisis. (Fuente: Prensa Gobernación)"><img class="show-for-large-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.285" data-src="https://images.pagina12.com.ar/styles/focal_16_9_470x264/public/2021-04/158244-ro03fo0127.jpg?itok=nTAN42ZV" alt="Javkin y Lagna coincidieron en el análisis. (Fuente: Prensa Gobernación)"><img class="show-for-xsmall-only  lazyload" src="https://www.pagina12.com.ar/assets/media/assets/transparent.gif?v=1.0.285" data-src="https://images.pagina12.com.ar/styles/focal_16_9_300x169/public/2021-04/158244-ro03fo0127.jpg?itok=twd1sGqN" alt="Javkin y Lagna coincidieron en el análisis. (Fuente: Prensa Gobernación)"><img class="show-for-xmedium-only  lazyload" src="http ...

# %%
# Muestra el encabezado con el que sale la respuesta
print(page12.request.headers)

# Muestra el encabezado de la respuesta
print(page12.headers)

# Muestra a que url le realiza la solicitud
print(page12.request.url)
# Out:
# {'User-Agent': 'python-requests/2.25.1', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
# {'Date': 'Wed, 28 Apr 2021 06:06:27 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=ded1d83a0743c8cd09ff499a51f0449fc1619589987; expires=Fri, 28-May-21 06:06:27 GMT; path=/; domain=.pagina12.com.ar; HttpOnly; SameSite=Lax', 'Vary': 'Accept-Encoding', 'X-DNS-Prefetch-Control': 'off', 'Strict-Transport-Security': 'max-age=15724800; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-ETag': 'W/"63b33-XxLbF8r702igICX1IO2avPPmi6k"', 'X-Backend': 'frontend', 'X-Backend-TTL': '180.000', 'X-Type': 'Dynamic URI', 'Age': '4', 'grace': '86400.000 none', 'ttl': '115.024', 'X-Instance': 'cache-front-prod-varnish-68cf7d4bd6-f8qpn', 'x-restarts': '0', 'X-Cache': 'HIT (20)', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '09b8af12fe0000e5c0b3289000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '646e1acb2a83e5c0-BOG', 'Content-Encoding': 'gzip'}
# https://www.pagina12.com.ar/

# %%
# Parseando el codeigo HTML

soup = BeautifulSoup(page12.text, 'lxml')
# Denta el codigo Html
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="no-js">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Página12 | La otra mirada\n  </title>\n  <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>\n  <script type="application/ld+json">\n   {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}\n  </script>\n  <meta content="Notas focalizadas en el quehacer político de la Argentina." name="description" property="description"/>\n  <meta content="1541638399393436" name="fb:pages" property="fb:pages"/>\n  <meta content="es_AR" name="og:locale" property="og:locale"/>\n  <meta content="Página12 | La otra mirada" name="og:title" property="og:title"/>\n  <meta content="PAGINA12" name="og:site_name" property="og:site_name"/>\n  <meta content="website" name="og:type" property="og:type"/>\n  <meta content="https://www.pagina12.com.ar" name="og:url" property="og:url"/>\n  <meta content="Notas focalizadas en el quehacer político de la Argentina." name="og:description" property="og:description"/>\n  <meta content="Página12 | La otra mirada" name="twitter:title" property="twitter:title"/>\n  <meta content="Notas focalizadas en el quehacer político de la Argentina." name="twitter:description" property="twitter:description"/>\n  <meta content="@Pagina12" name="twitter:creator" property="twitter:creator"/>\n  <meta content="@pagina12" name="twitter:site" property="twitter:site"/>\n  <meta content="Página12" name="article:author" property="article:author"/>\n  <meta content="https://www.facebook.com/Pagina12ok" name="article:publisher" property="article:publisher"/>\n  <meta content="https://www.pagina12.com.ar" name="share_cdn_host"/>\n  <meta content="width=device-width, initial-scale=1, minimum-scale=1, user-scalable=yes" name="viewport"/>\n  <link href="//cdn.jsdelivr.net/jquery.slick/1.6.0/slick.css" rel="stylesheet" type="text/css"/>\n  <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>\n  <link href="https://fonts.googleapis.com/css?family=Archivo+Narrow|Lora:400,400i|Oswald:300,400,700,800|Open+Sans+Condensed:300,700|Open+Sans:300,300i,400,400i,600,600i,700,800&amp;display=swap" rel="stylesheet"/>\n  <link href="https://www.pagina12.com.ar/assets/css/main.min.css?v=1.0.285" media="screen" rel="stylesheet"/>\n  <link href="https://www.pagina12.com.ar/assets/css/print.min.css?v=1.0.285" media="print" rel="stylesheet"/>\n  <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.285" rel="shortcut icon" type="image/x-icon"/>\n  <link href="https://www.pagina12.com.ar/favicon.ico?v=1.0.285" rel="icon" type="image/x-icon"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/57x57.png?v=1.0.285" rel="apple-touch-icon" sizes="57x57"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/72x72.png?v=1.0.285" rel="apple-touch-icon" sizes="72x72"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/114x114.png?v=1.0.285" rel="apple-touch-icon" sizes="114x114"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/120x120.png?v=1.0.285" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/144x144.png?v=1.0.285" rel="apple-touch-icon" sizes="144x144"/>\n  <link href="https://www.pagina12.com.ar/assets/media/favicon/152x152.png?v=1.0.285" rel="apple-touch-icon" sizes="152x152"/>\n  <script>\n   dataLayer = [];dataLayer.push({"section": "home"});dataLayer.push({"suplement": "home"});dataLayer.push({"listing": "home"});dataLayer.push({"search": "-"});dataLayer.push({"author": "-"});dataLayer.push({"id": "- ...

# %%
# Extrayendo datos del html parseado
# .find('tag') // busca el primer elemento
# .find_all('tag') // Retorna una lista con los elementos encontrados
secciones = soup.find('ul', attrs={'class': 'horizontal-list main-sections hide-on-dropdown'}).find_all('li')

# .get('atributo') // optiene algun atributo
# .get_text() // optiene el texto del elemento
secciones[0].find('a').get('href')
secciones[0].find('a').get_text()
# Out:
# 'El país'

# %%
# Alamacenando los textos y links obteniedos
links_secciones = [seccion.find('a').get('href') for seccion in secciones]
texto_secciones = [seccion.find('a').get_text() for seccion in secciones]
links_secciones
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/el-mundo',
#  'https://www.pagina12.com.ar/secciones/contratapa']

# %%
# Accediendo al primer link encontrado y extrayendo los articulos
"""
Lo habitual es capturar la expecion al usar peticiones a terceros
try:
    pass
except Exeption as e:
    pass


"""
# Descarga la pagina de la URL
page12_articles = requests.get(links_secciones[0])
print(page12_articles.status_code)

# Parsenado el html
soup_seccion_article = BeautifulSoup(page12_articles.text, 'lxml')

# Obteniendo el articulo principal
featured_article = soup_seccion_article.find('article', attrs={'class': 'article-item article-item--main'})
link_article = featured_article.find('h2', attrs={'class': 'title-list'}).find('a').get('href')
link_article
# Out:
# 200
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-7da81878c2af> in <module>
#      18 # Obteniendo el articulo principal
#      19 featured_article = soup_seccion_article.find('article', attrs={'class': 'article-item article-item--main'})
# ---> 20 link_article = featured_article.find('h2', attrs={'class': 'title-list'}).find('a').get('href')
#      21 link_article
#      22
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Extrayendo los demas links de las demas listas
articles_list = soup_seccion_article.find('div', attrs={'class': 'articles-list'}).find_all('div', attrs={
    'class': 'article-item__header'})

url_notas = []
for article in articles_list:
    url_notas.append(article.find('a').get('href'))

print(url_notas)

# %%
# Obteniendo la informacion para las notas

try:
    nota = requests.get(url_notas[0])
    if nota.status_code == 200:
        soup_nota = BeautifulSoup(nota.text, 'lxml')

        title = soup_nota.find('h1').getText()
        fecha = soup_nota.find('span', attrs={'pubdate': 'pubdate'}).get('datetime')
        image = soup_nota.find('figure', attrs={'class': 'object-fit-block--contain intrinsic-container intrinsic-container-3x2'}).find_all('img')[0].get('data-src')

        # Download image
        img_req = requests.get(image)
        # Permite rendedirazr el contenido en Jupiter
        # content accede al contenido binario del archivo
        Image(img_req.content)


except Exception as error:
    print('Error: ')
    print(error)
    print('\n\n')
